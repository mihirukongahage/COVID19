# %% [markdown]
# <a href="https://colab.research.google.com/github/mihirukongahage/COVID19/blob/master/COVID19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# imports
import io
import pandas as pd

# %%
# dataset upload
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ac150519-60c4-4202-abbb-3a27401a007f" name="files[]" multiple disabled />
#      <output id="result-ac150519-60c4-4202-abbb-3a27401a007f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving COVID19.csv to COVID19.csv

# %%
df2 = pd.read_csv(io.BytesIO(uploaded['COVID19.csv']))

# %%
df2
# Out:
#         id  case_in_country  ... Unnamed: 25  Unnamed: 26
# 0        1              NaN  ...         NaN          NaN
# 1        2              NaN  ...         NaN          NaN
# 2        3              NaN  ...         NaN          NaN
# 3        4              NaN  ...         NaN          NaN
# 4        5              NaN  ...         NaN          NaN
# ...    ...              ...  ...         ...          ...
# 1080  1081              2.0  ...         NaN          NaN
# 1081  1082              1.0  ...         NaN          NaN
# 1082  1083              1.0  ...         NaN          NaN
# 1083  1084              1.0  ...         NaN          NaN
# 1084  1085              1.0  ...         NaN          NaN
#
# [1085 rows x 27 columns]

# %%
df2 = df2.drop(['Unnamed: 3', 'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26', 'id', 'summary'], axis=1)
df2
# Out:
#       case_in_country  ...                                               link
# 0                 NaN  ...  http://wjw.sz.gov.cn/wzx/202001/t20200120_1898...
# 1                 NaN  ...  https://www.weibo.com/2372649470/IqogQhgfa?fro...
# 2                 NaN  ...  http://www.zjwjw.gov.cn/art/2020/1/21/art_1202...
# 3                 NaN  ...        https://m.weibo.cn/status/4463235401268457?
# 4                 NaN  ...        https://m.weibo.cn/status/4463235401268457?
# ...               ...  ...                                                ...
# 1080              2.0  ...  https://www.thejakartapost.com/news/2020/02/25...
# 1081              1.0  ...  https://www.foxnews.com/health/afghanistan-fir...
# 1082              1.0  ...  https://www.scmp.com/news/china/society/articl...
# 1083              1.0  ...  https://www.reuters.com/article/us-croatia-cor...
# 1084              1.0  ...  https://www.reuters.com/article/uk-switzerland...
#
# [1085 rows x 18 columns]
